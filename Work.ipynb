# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\ROSHAN\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd

df    = pd.read_csv(r'C:\Users\ROSHAN\Documents\GitHub\Song-Clustering\Data\Extraction\Dataset.csv')

# %%
df
# Out:
#               artist                            album  \
# 0     Zac Brown Band                   The Foundation
# 1     Zac Brown Band   You Get What You Give (Deluxe)
# 2     Eli Young Band                     Life At Best
# 3         Luke Bryan             Tailgates & Tanlines
# 4         Luke Bryan                 Kick The Dust Up
# ..               ...                              ...
# 910         Pandrezz                         Sketches
# 911         Pandrezz                         Sketches
# 912  Various Artists  Chillhop Essentials Winter 2017
# 913       Elijah Who                     new feelings
# 914       Elijah Who                     new feelings
#
#                                      track_name                track_id  \
# 0                                 Chicken Fried  4dGJf1SER1T6ooX46vwzRB
# 1    As She's Walking Away (feat. Alan Jackson)  5qYiVdWxd84wRWGIQ9Hts6
# 2                                    Crazy Girl  1nVLAEzhBXMJLR5zAl90Nl
# 3                                  Drunk On You  3b7CDTKB0SRTmQ6ytYi5vZ
# 4                              Kick The Dust Up  4LaKcWRqoZKnN626xheqM2
# ..                                          ...                     ...
# 910                                    Sketches  2sDwMd2WIrVn81u9lCQaU9
# 911                                      Garden  7eyqqiXlFXkjl6i3saJuVO
# 912                                      pianos  0IDToYzep0msYZcYL3NINn
# 913                                        -3 u  6ZaPpn0Wev0DEsrUv87ctJ
# 914                                 so far away  1JYz22iCqxPxozNspW2bWu
#
#      acousticness  danceability  energy  key  loudness  mode  speechiness  \
# 0        0.645000         0.566   0.713    6    -4.250     1       0.0417
# 1        0.474000         0.553   0.619    3    -7.101     1       0.0308
# 2        0.000415         0.366   0.651    4    -3.842     1       0.0310
# 3        0.178000         0.558   0.872    9    -4.401     1       0.0449
# 4        0.180000         0.596   0.858    1    -2.377     1       0.0493
# ..            ...           ...     ...  ...       ...   ...          ...
# 910      0.600000         0.735   0.411   10   -10.249     1       0.0634
# 911      0.887000         0.458   0.165    8   -15.471     0       0.0673
# 912      0.662000         0.624   0.404    9   -10.891     0       0.3470
# 913      0.599000         0.487   0.415    5    -6.837     0       0.2360
# 914      0.915000         0.757   0.163    0   -14.820     1       0.0429
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.00000    0.1140    0.807  169.864       238147
# 1             0.00000    0.1230    0.374  183.910       223827
# 2             0.00526    0.2710    0.257  151.343       200707
# 3             0.00000    0.1730    0.472  143.971       213547
# 4             0.00000    0.3210    0.819  172.108       192906
# ..                ...       ...      ...      ...          ...
# 910           0.93800    0.1120    0.354  158.177        92289
# 911           0.11900    0.1640    0.157   75.866        92350
# 912           0.88600    0.4200    0.585   79.903       125348
# 913           0.26000    0.0994    0.830   77.850       130377
# 914           0.78200    0.3290    0.631  149.993       129045
#
#      time_signature  Cluster
# 0                 4        0
# 1                 4        0
# 2                 3        0
# 3                 4        0
# 4                 4        0
# ..              ...      ...
# 910               4        2
# 911               3        2
# 912               4        2
# 913               4        2
# 914               4        2
#
# [915 rows x 18 columns]

# %%
df.head(5)
# Out:
#            artist                           album  \
# 0  Zac Brown Band                  The Foundation
# 1  Zac Brown Band  You Get What You Give (Deluxe)
# 2  Eli Young Band                    Life At Best
# 3      Luke Bryan            Tailgates & Tanlines
# 4      Luke Bryan                Kick The Dust Up
#
#                                    track_name                track_id  \
# 0                               Chicken Fried  4dGJf1SER1T6ooX46vwzRB
# 1  As She's Walking Away (feat. Alan Jackson)  5qYiVdWxd84wRWGIQ9Hts6
# 2                                  Crazy Girl  1nVLAEzhBXMJLR5zAl90Nl
# 3                                Drunk On You  3b7CDTKB0SRTmQ6ytYi5vZ
# 4                            Kick The Dust Up  4LaKcWRqoZKnN626xheqM2
#
#    acousticness  danceability  energy  key  loudness  mode  speechiness  \
# 0      0.645000         0.566   0.713    6    -4.250     1       0.0417
# 1      0.474000         0.553   0.619    3    -7.101     1       0.0308
# 2      0.000415         0.366   0.651    4    -3.842     1       0.0310
# 3      0.178000         0.558   0.872    9    -4.401     1       0.0449
# 4      0.180000         0.596   0.858    1    -2.377     1       0.0493
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00000     0.114    0.807  169.864       238147               4
# 1           0.00000     0.123    0.374  183.910       223827               4
# 2           0.00526     0.271    0.257  151.343       200707               3
# 3           0.00000     0.173    0.472  143.971       213547               4
# 4           0.00000     0.321    0.819  172.108       192906               4
#
#    Cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df.corr()
# Out:
#                   acousticness  danceability    energy       key  loudness  \
# acousticness          1.000000      0.516877 -0.874771  0.041631 -0.798877
# danceability          0.516877      1.000000 -0.587010  0.038086 -0.446501
# energy               -0.874771     -0.587010  1.000000 -0.039267  0.877009
# key                   0.041631      0.038086 -0.039267  1.000000 -0.035222
# loudness             -0.798877     -0.446501  0.877009 -0.035222  1.000000
# mode                 -0.044869      0.045949  0.034879 -0.126375  0.070673
# speechiness          -0.100816     -0.193673  0.121543  0.030011  0.051293
# instrumentalness      0.495446      0.137651 -0.469883  0.033202 -0.565333
# liveness             -0.254570     -0.284412  0.321689 -0.027025  0.238866
# valence              -0.114799      0.299849  0.081971  0.019108  0.191728
# tempo                -0.217160     -0.209112  0.244127  0.010249  0.219565
# duration_ms          -0.564623     -0.475522  0.589518 -0.051867  0.518294
# time_signature        0.033876      0.130182  0.005101  0.042525 -0.001147
# Cluster               0.594990      0.190545 -0.568345  0.042616 -0.659544
#
#                       mode  speechiness  instrumentalness  liveness   valence  \
# acousticness     -0.044869    -0.100816          0.495446 -0.254570 -0.114799
# danceability      0.045949    -0.193673          0.137651 -0.284412  0.299849
# energy            0.034879     0.121543         -0.469883  0.321689  0.081971
# key              -0.126375     0.030011          0.033202 -0.027025  0.019108
# loudness          0.070673     0.051293         -0.565333  0.238866  0.191728
# mode              1.000000    -0.178988         -0.185963 -0.041666  0.149050
# speechiness      -0.178988     1.000000          0.216947  0.177560 -0.196639
# instrumentalness -0.185963     0.216947          1.000000 -0.075636 -0.384700
# liveness         -0.041666     0.177560         -0.075636  1.000000 -0.090093
# valence           0.149050    -0.196639         -0.384700 -0.090093  1.000000
# tempo             0.097918     0.075634         -0.160273  0.059209  0.130770
# duration_ms       0.006640     0.015525         -0.349938  0.149393 -0.086483
# time_signature    0.060173    -0.061332         -0.048852 -0.035364  0.104186
# Cluster          -0.240674     0.307860          0.810467 -0.065972 -0.487899
#
#                      tempo  duration_ms  time_signature   Cluster
# acousticness     -0.217160    -0.564623        0.033876  0.594990
# danceability     -0.209112    -0.475522        0.130182  0.190545
# energy            0.244127     0.589518        0.005101 -0.568345
# key               0.010249    -0.051867        0.042525  0.042616
# loudness          0.219565     0.518294       -0.001147 -0.659544
# mode              0.097918     0.006640        0.060173 -0.240674
# speechiness       0.075634     0.015525       -0.061332  0.307860
# instrumentalness -0.160273    -0.349938       -0.048852  0.810467
# liveness          0.059209     0.149393       -0.035364 -0.065972
# valence           0.130770    -0.086483        0.104186 -0.487899
# tempo             1.000000     0.134172        0.039848 -0.206308
# duration_ms       0.134172     1.000000        0.054467 -0.431184
# time_signature    0.039848     0.054467        1.000000 -0.087372
# Cluster          -0.206308    -0.431184       -0.087372  1.000000

# %%
df.describe()
# Out:
#        acousticness  danceability      energy         key    loudness  \
# count    915.000000    915.000000  915.000000  915.000000  915.000000
# mean       0.315918      0.523705    0.623204    5.310383   -8.419752
# std        0.354221      0.159463    0.324259    3.488313    5.289292
# min        0.000002      0.000000    0.019200    0.000000  -32.907000
# 25%        0.000300      0.427500    0.308500    2.000000  -11.974000
# 50%        0.130000      0.534000    0.714000    6.000000   -6.308000
# 75%        0.647500      0.642500    0.940500    8.000000   -4.456000
# max        0.991000      0.928000    0.999000   11.000000   -0.711000
#
#              mode  speechiness  instrumentalness    liveness     valence  \
# count  915.000000   915.000000        915.000000  915.000000  915.000000
# mean     0.716940     0.094037          0.411024    0.182707    0.329405
# std      0.450732     0.086672          0.404096    0.140323    0.228789
# min      0.000000     0.000000          0.000000    0.021700    0.000000
# 25%      0.000000     0.036500          0.000009    0.097700    0.142000
# 50%      1.000000     0.059400          0.278000    0.117000    0.267000
# 75%      1.000000     0.124000          0.857000    0.238500    0.493500
# max      1.000000     0.935000          0.977000    0.985000    0.966000
#
#             tempo   duration_ms  time_signature     Cluster
# count  915.000000  9.150000e+02      915.000000  915.000000
# mean   119.574341  2.030502e+05        3.856831    1.000000
# std     34.205567  6.917668e+04        0.521155    0.816943
# min      0.000000  1.181100e+04        0.000000    0.000000
# 25%     89.184000  1.574725e+05        4.000000    0.000000
# 50%    116.444000  1.996250e+05        4.000000    1.000000
# 75%    143.927000  2.348475e+05        4.000000    2.000000
# max    218.659000  1.060186e+06        5.000000    2.000000

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Checking if the data columns are in correct format

# %%
df.dtypes
# Out:
# artist               object
# album                object
# track_name           object
# track_id             object
# acousticness        float64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# Cluster               int64
# dtype: object

# %% [markdown]
# All the columns are in the intended data type

# %% [markdown]
# #### Checking for Null Values

# %%
df.isnull().sum()
# Out:
# artist              0
# album               0
# track_name          0
# track_id            0
# acousticness        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# Cluster             0
# dtype: int64

# %% [markdown]
# No Null values

# %% [markdown]
# #### Data Standardizing

# %% [markdown]
# Converting the duration into minutes from seconds

# %%
df["duration_ms"]=(df["duration_ms"]/(1000*60))%60  #Convert to minutes
df.head()
# Out:
#            artist                           album  \
# 0  Zac Brown Band                  The Foundation
# 1  Zac Brown Band  You Get What You Give (Deluxe)
# 2  Eli Young Band                    Life At Best
# 3      Luke Bryan            Tailgates & Tanlines
# 4      Luke Bryan                Kick The Dust Up
#
#                                    track_name                track_id  \
# 0                               Chicken Fried  4dGJf1SER1T6ooX46vwzRB
# 1  As She's Walking Away (feat. Alan Jackson)  5qYiVdWxd84wRWGIQ9Hts6
# 2                                  Crazy Girl  1nVLAEzhBXMJLR5zAl90Nl
# 3                                Drunk On You  3b7CDTKB0SRTmQ6ytYi5vZ
# 4                            Kick The Dust Up  4LaKcWRqoZKnN626xheqM2
#
#    acousticness  danceability  energy  key  loudness  mode  speechiness  \
# 0      0.645000         0.566   0.713    6    -4.250     1       0.0417
# 1      0.474000         0.553   0.619    3    -7.101     1       0.0308
# 2      0.000415         0.366   0.651    4    -3.842     1       0.0310
# 3      0.178000         0.558   0.872    9    -4.401     1       0.0449
# 4      0.180000         0.596   0.858    1    -2.377     1       0.0493
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00000     0.114    0.807  169.864     3.969117               4
# 1           0.00000     0.123    0.374  183.910     3.730450               4
# 2           0.00526     0.271    0.257  151.343     3.345117               3
# 3           0.00000     0.173    0.472  143.971     3.559117               4
# 4           0.00000     0.321    0.819  172.108     3.215100               4
#
#    Cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### Model Planning - Exploratory Data Analysis

# %%
energy_max=df["energy"].max() #Find song with maximum energy
print(energy_max)
df.query('energy == @energy_max')
# Out:
# 0.999
#        artist                              album  \
# 563  Cenotaph  Perverse Dehumanized Dysfunctions
#
#                            track_name                track_id  acousticness  \
# 563  Rancid Gluttonous Morbid Obesity  1uqTgkgdbf9Lf0f2b0lmcc      0.000119
#
#      danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 563         0.437   0.999    1    -3.574     1         0.21             0.947
#
#      liveness  valence    tempo  duration_ms  time_signature  Cluster
# 563     0.234   0.0384  114.997     3.693583               4        1

# %%
acoustic_max=df["acousticness"].max()  #Find song with maximum acousticness
print(acoustic_max)
df.query('acousticness == @acoustic_max')
# Out:
# 0.991
#      artist         album track_name                track_id  acousticness  \
# 736  mell-ø  Afloat Again   Epilogue  5zZY5LXTgeTmuPMR0bTgJW         0.991
#
#      danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 736         0.535  0.0843    9   -23.232     1       0.0534             0.899
#
#      liveness  valence   tempo  duration_ms  time_signature  Cluster
# 736     0.096    0.268  71.992     0.833333               4        2

# %%
dance_max=df["danceability"].max()  #Find song with maximum danceability
print(dance_max) 
df.query('danceability == @dance_max')
# Out:
# 0.928
#       artist             album track_name                track_id  \
# 885  Delayde  finding solitude      amber  7svJ308NOS6EMHd7D1YZnw
#
#      acousticness  danceability  energy  key  loudness  mode  speechiness  \
# 885         0.424         0.928   0.305   11   -16.385     0        0.223
#
#      instrumentalness  liveness  valence   tempo  duration_ms  time_signature  \
# 885             0.734    0.0792    0.234  133.98     1.962683               4
#
#      Cluster
# 885        2

# %%
#Plots for the Cluster 0 
fig, axes = plt.subplots(nrows=5, ncols=2,figsize=(15,30))
display=["acousticness","danceability", "loudness" ,"tempo","duration_ms",
                 "energy" ,"speechiness" ,"instrumentalness" ,
                 "liveness" ,"valence"]

yes=[0,0,0,1,1,0,1,1,2,0,2,1,3,0,3,1,4,0,4,1]
count=0
df_country = df[0:305]
for column in display:
    sns.distplot(df_country[column],ax=axes[yes[count],yes[count+1]],
                 bins=40,kde=True,color='r',norm_hist=False)
    count+=2

# %%
#Plots for the Cluster 1
fig, axes = plt.subplots(nrows=5, ncols=2,figsize=(15,30))
display=["acousticness","danceability", "loudness" ,"tempo","duration_ms",
                 "energy" ,"speechiness" ,"instrumentalness" ,
                 "liveness" ,"valence"]

yes=[0,0,0,1,1,0,1,1,2,0,2,1,3,0,3,1,4,0,4,1]
count=0
df_death_metal = df[305:610]
for column in display:
    sns.distplot(df_death_metal[column],ax=axes[yes[count],yes[count+1]],
                 bins=40,kde=True,color='r',norm_hist=False)
    count+=2

# %%
#Plots for the Cluster 2
fig, axes = plt.subplots(nrows=5, ncols=2,figsize=(15,30))
display=["acousticness","danceability", "loudness" ,"tempo","duration_ms",
                 "energy" ,"speechiness" ,"instrumentalness" ,
                 "liveness" ,"valence"]

yes=[0,0,0,1,1,0,1,1,2,0,2,1,3,0,3,1,4,0,4,1]
count=0
df_lofi = df[610:]
for column in display:
    sns.distplot(df_lofi[column],ax=axes[yes[count],yes[count+1]],
                 bins=40,kde=True,color='r',norm_hist=False)
    count+=2
